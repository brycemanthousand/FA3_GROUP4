# %% [markdown]
# # 1. The volume of a sphere with radius r is 43πr3. What is the volume of a sphere with radius 5?

# %%
r = float(input("Enter radius: "))
V = (4/3) * 3.14 * (r**3)

print("The volume of the sphere is:", V)
# Out:
# Enter radius:  23
# The volume of the sphere is: 50939.17333333333

# %% [markdown]
# # 2. Suppose the cover price of a book is 24.95, but bookstores get a 40% discount. Shipping costs 3 for the first copy and 75 cents for each additional copy. What is the total wholesale cost for 60 copies?

# %%
coverPrice = 24.95
discount = 0.4 
priceFirst = 3.00
priceAdditional = 0.75
copies = int(input("Enter number of copies: "))

bookDiscount = coverPrice * (1 - discount) * copies
shipping = priceAdditional * (copies - 1) + priceFirst
totalWholesaleCost = bookDiscount + shipping

print("The total wholesale cost for", copies, " copies is: $", round(totalWholesaleCost, 2))
# Out:
# Enter number of copies:  200000
# The total wholesale cost for 200000  copies is: $ 3144002.25

# %% [markdown]
# # 3. If I leave my house at 6:52 am and run 1 mile at an easy pace (8:15 per mile), then 3 miles at tempo (7:12 per mile) and 1 mile at an easy pace again, what time do I get home for breakfast?

# %%
mile1=495
mile2=434
time=(2*mile1)+(3*mile2)
currtime=24720
endtimeS=(currtime+time)
endtime=(currtime+time)/3600

print('Your total time of running in terms of seconds is',time)
print(',you started running at 6:52 am, you will arrive at home at',endtime)  
print('in terms of time, that is 7:30 am')
# Out:
# Your total time of running in terms of seconds is 2292
# ,you started running at 6:52 am, you will arrive at home at 7.503333333333333
# in terms of time, that is 7:30 am
